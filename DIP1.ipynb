# %% [markdown]
# # Using PIL

# %%
from PIL import Image

image = Image.open("D:\\flower.jpg")

image.show()

# %%
image.save("D:\\new_flower.jpg")

# %% [markdown]
# # Using Matplotlib

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg


image = mpimg.imread("D:\\flower.jpg")


plt.imshow(image)
plt.show()


plt.imsave("D:\\flower_Matplotlib.jpg", image)

# %% [markdown]
# # Using Scikit-image

# %%
from skimage import io


image = io.imread("D:\\flower.jpg")


io.imshow(image)
io.show()

io.imsave("D:\\flower_Scikit.jpg", image)6
